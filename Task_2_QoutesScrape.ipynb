# %% [markdown]
# # Quotes to Scrape - Web Scraping Results
#
# ##  Author List
#
# ```javascript
# document.querySelectorAll('small')[0].textContent
# // 'Albert Einstein'
# document.querySelectorAll('small')[1].textContent
# // 'J.K. Rowling'
# document.querySelectorAll('small')[2].textContent
# // 'Albert Einstein'
# document.querySelectorAll('small')[3].textContent
# // 'Jane Austen'
# document.querySelectorAll('small')[4].textContent
# // 'Marilyn Monroe'
# document.querySelectorAll('small')[5].textContent
# // 'Albert Einstein'
# document.querySelectorAll('small')[6].textContent
# // 'André Gide'
# document.querySelectorAll('small')[7].textContent
# // 'Thomas A. Edison'
# document.querySelectorAll('small')[8].textContent
# // 'Eleanor Roosevelt'
# document.querySelectorAll('small')[9].textContent
# // 'Steve Martin'
# ```
#
# ---
#
# ##  Top Ten Tag List
#
# ```javascript
# document.querySelector('h2').textContent
# // 'Top Ten tags'
# document.querySelectorAll('span')[21].querySelector('a').textContent
# // 'love'
# document.querySelectorAll('span')[25].querySelector('a').textContent
# // 'books'
# document.querySelectorAll('span')[23].querySelector('a').textContent
# // 'life'
# document.querySelectorAll('span')[29].querySelector('a').textContent
# // 'truth'
# document.querySelectorAll('span')[27].querySelector('a').textContent
# // 'friendship'
# document.querySelectorAll('span')[28].querySelector('a').textContent
# // 'friends'
# document.querySelectorAll('span')[22].querySelector('a').textContent
# // 'inspirational'
# document.querySelectorAll('span')[24].querySelector('a').textContent
# // 'humor'
# document.querySelectorAll('span')[26].querySelector('a').textContent
# // 'reading'
# document.querySelectorAll('span')[30].querySelector('a').textContent
# // 'simile'
# ```
#
# ---
#
# ##  Quote List
#
# ```javascript
# document.querySelectorAll('div')[0].querySelectorAll('span')[2].textContent
# // “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[4].textContent
# // “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[3].textContent
# // by J.K. Rowling (about)
# document.querySelectorAll('div')[0].querySelectorAll('span')[5].textContent
# // by Albert Einstein (about)
# document.querySelectorAll('div')[0].querySelectorAll('span')[6].textContent
# // “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[8].textContent
# // “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[10].textContent
# // “Try not to become a man of success. Rather become a man of value.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[12].textContent
# // “It is better to be hated for what you are than to be loved for what you are not.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[14].textContent
# // “I have not failed. I've just found 10,000 ways that won't work.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[16].textContent
# // “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[18].textContent
# // “A day without sunshine is like, you know, night.”
# document.querySelectorAll('div')[0].querySelectorAll('span')[19].textContent
# // by Steve Martin (about)
# ```
